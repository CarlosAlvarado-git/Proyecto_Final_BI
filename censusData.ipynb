# %%
import pandas as pd
import numpy as np
import psycopg2
import psycopg2.extras as extras
import os
import re

path = 'C:/GitHub/Proyecto_Final_BI/'

# %%
# función dada en clase
def load_data(filename):
    """ Load dataset from filename
    Args:
        filename (string): Path to data
        
    Returns:
        df (DataFrame): Dataset from file
    """
    df = pd.read_csv(filename)
    return df

# %%
def trim_all_columns(df):
    """
    Trim whitespace from ends of each value across all series in dataframe
    """
    trim_strings = lambda x: x.strip() if isinstance(x, str) else x
    return df.applymap(trim_strings)

# %%
filename = os.path.join(path,'ageAndSex_S0101.csv')
age_and_sex = load_data(filename)

# %%
age_and_sex.head()
# Out:
#          Label (Grouping) United States!!Total!!Estimate  \
# 0        Total population                    331,893,745
# 1                     AGE                            NaN
# 2           Under 5 years                     18,661,245
# 3            5 to 9 years                     20,010,813
# 4          10 to 14 years                     21,821,492
#
#   United States!!Total!!Margin of Error United States!!Percent!!Estimate  \
# 0                                 *****                              (X)
# 1                                   NaN                              NaN
# 2                               ±17,131                             5.6%
# 3                               ±69,083                             6.0%
# 4                               ±72,184                             6.6%
#
#   United States!!Percent!!Margin of Error United States!!Male!!Estimate  \
# 0                                     (X)                   164,350,703
# 1                                     NaN                           NaN
# 2                                    ±0.1                     9,552,445
# 3                                    ±0.1                    10,284,656
# 4                                    ±0.1                    11,155,383
#
#   United States!!Male!!Margin of Error United States!!Percent Male!!Estimate  \
# 0                              ±26,594                                   (X)
# 1                                  NaN                                   NaN
# 2                              ±19,155                                  5.8%
# 3                              ±48,771                                  6.3%
# 4                              ±50,933                                  6.8%
#
#   United States!!Percent Male!!Margin of Error  \
# 0                                          (X)
# 1                                          NaN
# 2                                         ±0.1
# 3                                         ±0.1
# 4                                         ±0.1
#
#   United States!!Female!!Estimate  ... Texas!!Percent!!Estimate  \
# 0                     167,543,042  ...                      (X)
# 1                             NaN  ...                      NaN
# 2                       9,108,800  ...                     6.4%
# 3                       9,726,157  ...                     7.0%
# 4                      10,666,109  ...                     7.5%
#
#   Texas!!Percent!!Margin of Error Texas!!Male!!Estimate  \
# 0                             (X)            14,739,011
# 1                             NaN                   NaN
# 2                            ±0.1               967,416
# 3                            ±0.1             1,059,471
# 4                            ±0.1             1,119,382
#
#   Texas!!Male!!Margin of Error Texas!!Percent Male!!Estimate  \
# 0                      ±10,620                           (X)
# 1                          NaN                           NaN
# 2                       ±6,962                          6.6%
# 3                      ±19,232                          7.2%
# 4                      ±19,737                          7.6%
#
#   Texas!!Percent Male!!Margin of Error Texas!!Female!!Estimate  \
# 0                                  (X)              14,788,930
# 1                                  NaN                     NaN
# 2                                 ±0.1                 924,211
# 3                                 ±0.1                 996,336
# 4                                 ±0.1               1,087,144
#
#   Texas!!Female!!Margin of Error Texas!!Percent Female!!Estimate  \
# 0                        ±10,620                             (X)
# 1                            NaN                             NaN
# 2                         ±6,596                            6.2%
# 3                        ±17,283                            6.7%
# 4                        ±16,395                            7.4%
#
#   Texas!!Percent Female!!Margin of Error
# 0                                    (X)
# 1                                    NaN
# 2                                   ±0.1
# 3                                   ±0.1
# 4                                   ±0.1
#
# [5 rows x 25 columns]

# %%
age_and_sex.columns
# Out:
# Index(['Label (Grouping)', 'United States!!Total!!Estimate',
#        'United States!!Total!!Margin of Error',
#        'United States!!Percent!!Estimate',
#        'United States!!Percent!!Margin of Error',
#        'United States!!Male!!Estimate', 'United States!!Male!!Margin of Error',
#        'United States!!Percent Male!!Estimate',
#        'United States!!Percent Male!!Margin of Error',
#        'United States!!Female!!Estimate',
#        'United States!!Female!!Margin of Error',
#        'United States!!Percent Female!!Estimate',
#        'United States!!Percent Female!!Margin of Error',
#        'Texas!!Total!!Estimate', 'Texas!!Total!!Margin of Error',
#        'Texas!!Percent!!Estimate', 'Texas!!Percent!!Margin of Error',
#        'Texas!!Male!!Estimate', 'Texas!!Male!!Margin of Error',
#        'Texas!!Percent Male!!Estimate', 'Texas!!Percent Male!!Margin of Error',
#        'Texas!!Female!!Estimate', 'Texas!!Female!!Margin of Error',
#        'Texas!!Percent Female!!Estimate',
#        'Texas!!Percent Female!!Margin of Error'],
#       dtype='object')

# %%
size = age_and_sex.shape
States = ["Texas", "Ohio"]
for i in list(age_and_sex.columns.values):
    for j in States:
        if i.find(j) != -1:
            a = ["TX"]
            b = a*(size[0])
            break
age_and_sex['State'] = b

# %%
age_and_sex = age_and_sex.drop(columns = [
     'United States!!Total!!Estimate',
       'United States!!Total!!Margin of Error',
       'United States!!Percent!!Estimate',
       'United States!!Percent!!Margin of Error',
       'United States!!Male!!Estimate', 
       'United States!!Male!!Margin of Error',
       'United States!!Percent Male!!Estimate',
       'United States!!Percent Male!!Margin of Error',
       'United States!!Female!!Estimate',
       'United States!!Female!!Margin of Error',
       'United States!!Percent Female!!Estimate',
       'United States!!Percent Female!!Margin of Error',
       'Texas!!Total!!Estimate', 
       'Texas!!Total!!Margin of Error',
       'Texas!!Percent!!Estimate', 
       'Texas!!Percent!!Margin of Error',
       'Texas!!Male!!Estimate', 
       'Texas!!Male!!Margin of Error',
       'Texas!!Percent Male!!Estimate', 
       'Texas!!Percent Male!!Margin of Error',
       'Texas!!Female!!Estimate', 
       'Texas!!Female!!Margin of Error',
       'Texas!!Percent Female!!Estimate',
       'Texas!!Percent Female!!Margin of Error'])

# %%
age_and_sex = trim_all_columns(age_and_sex)

# %%
age_and_sex = age_and_sex.drop(age_and_sex.index[20:42])
age_and_sex = age_and_sex.drop(age_and_sex.index[0:5])

# %%
age_and_sex
# Out:
#              ageRange State
# 0       0 to 14 years    TX
# 1      15 to 19 years    TX
# 2      20 to 24 years    TX
# 3      25 to 29 years    TX
# 4      30 to 34 years    TX
# 5      35 to 39 years    TX
# 6      40 to 44 years    TX
# 7      45 to 49 years    TX
# 8      50 to 54 years    TX
# 9      55 to 59 years    TX
# 10     60 to 64 years    TX
# 11     65 to 69 years    TX
# 12     70 to 74 years    TX
# 13     75 to 79 years    TX
# 14     80 to 84 years    TX
# 15  85 years and over    TX

# %%
age_and_sex.rename(columns = {'Label (Grouping)':'ageRange'}, inplace = True)

# %%
range0 = pd.DataFrame({'ageRange':['0 to 14 years'],'State':a})

# %%
age_and_sex = pd.concat([range0, age_and_sex], ignore_index=True)

# %%
filename = os.path.join(path,'medianIncome_S1903.csv')
income = load_data(filename)

# %%
income.head()
# Out:
#                                     Label (Grouping)  \
# 0  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATIN...
# 1                                         Households
# 2                                         One race--
# 3                                              White
# 4                          Black or African American
#
#   United States!!Number!!Estimate United States!!Number!!Margin of Error  \
# 0                             NaN                                    NaN
# 1                     127,544,730                                ±97,632
# 2                             NaN                                    NaN
# 3                      85,344,506                                ±82,195
# 4                      15,274,070                                ±42,592
#
#   United States!!Percent Distribution!!Estimate  \
# 0                                           NaN
# 1                                   127,544,730
# 2                                           NaN
# 3                                         66.9%
# 4                                         12.0%
#
#   United States!!Percent Distribution!!Margin of Error  \
# 0                                                NaN
# 1                                            ±97,632
# 2                                                NaN
# 3                                               ±0.1
# 4                                               ±0.1
#
#   United States!!Median income (dollars)!!Estimate  \
# 0                                              NaN
# 1                                           69,717
# 2                                              NaN
# 3                                           74,932
# 4                                           46,774
#
#   United States!!Median income (dollars)!!Margin of Error  \
# 0                                                NaN
# 1                                               ±134
# 2                                                NaN
# 3                                               ±163
# 4                                               ±335
#
#   Texas!!Number!!Estimate Texas!!Number!!Margin of Error  \
# 0                     NaN                            NaN
# 1              10,796,247                        ±19,104
# 2                     NaN                            NaN
# 3               5,712,732                        ±25,952
# 4               1,383,244                        ±13,574
#
#   Texas!!Percent Distribution!!Estimate  \
# 0                                   NaN
# 1                            10,796,247
# 2                                   NaN
# 3                                 52.9%
# 4                                 12.8%
#
#   Texas!!Percent Distribution!!Margin of Error  \
# 0                                          NaN
# 1                                      ±19,104
# 2                                          NaN
# 3                                         ±0.2
# 4                                         ±0.1
#
#   Texas!!Median income (dollars)!!Estimate  \
# 0                                      NaN
# 1                                   66,963
# 2                                      NaN
# 3                                   77,631
# 4                                   49,767
#
#   Texas!!Median income (dollars)!!Margin of Error
# 0                                             NaN
# 1                                            ±513
# 2                                             NaN
# 3                                            ±765
# 4                                          ±1,172

# %%
income.columns
# Out:
# Index(['Label (Grouping)', 'United States!!Number!!Estimate',
#        'United States!!Number!!Margin of Error',
#        'United States!!Percent Distribution!!Estimate',
#        'United States!!Percent Distribution!!Margin of Error',
#        'United States!!Median income (dollars)!!Estimate',
#        'United States!!Median income (dollars)!!Margin of Error',
#        'Texas!!Number!!Estimate', 'Texas!!Number!!Margin of Error',
#        'Texas!!Percent Distribution!!Estimate',
#        'Texas!!Percent Distribution!!Margin of Error',
#        'Texas!!Median income (dollars)!!Estimate',
#        'Texas!!Median income (dollars)!!Margin of Error'],
#       dtype='object')

# %%
income = income.drop(columns = [
    'United States!!Number!!Estimate',
    'United States!!Number!!Margin of Error',
    'United States!!Percent Distribution!!Estimate',
    'United States!!Percent Distribution!!Margin of Error',
    'United States!!Median income (dollars)!!Estimate',
    'United States!!Median income (dollars)!!Margin of Error',
    'Texas!!Number!!Margin of Error',
    'Texas!!Percent Distribution!!Estimate',
    'Texas!!Percent Distribution!!Margin of Error',
    'Texas!!Median income (dollars)!!Estimate',
    'Texas!!Median income (dollars)!!Margin of Error'
])

# %%
income = income.drop(income.index[17:47])
income = income.drop(income.index[0:13])

# %%
size = income.shape
States = ["Texas", "Ohio"]
for i in list(income.columns.values):
    for j in States:
        if i.find(j) != -1:
            a = ["TX"]
            b = a*size[0]
            break
income['State'] = b

# %%
income.rename(columns = {'Label (Grouping)':'ageRange'}, inplace = True)
income.rename(columns = {'Texas!!Number!!Estimate':'income'}, inplace = True)

# %%
income['income'] = income['income'].str.replace(',', '')

# %%
income = income.astype({'income':'int'})

# %%
income
# Out:
#                  ageRange   income State
# 13         15 to 24 years   530049    TX
# 14         25 to 44 years  4057366    TX
# 15         45 to 64 years  3841670    TX
# 16      65 years and over  2367162    TX

# %%
ages = income.iloc[:,0]
incomes = income.iloc[:,1]
incomes = np.asarray(incomes)

# %%
dfAges = pd.DataFrame()
baseLimit  = []
upperLimit = []
for item in ages:
    numbers = re.findall(r'\d+', item)
    baseLimit.append(int(numbers[0]))
    if len(numbers) > 1:
        upperLimit.append(int(numbers[1]))
    else:
        upperLimit.append(-1)
dfAges['baseLimit'] = baseLimit
dfAges['upperLimit'] = upperLimit
dfAges['income'] = incomes
dfAges
# Out:
#    baseLimit  upperLimit   income
# 0         15          24   530049
# 1         25          44  4057366
# 2         45          64  3841670
# 3         65          -1  2367162

# %%
people_1 = pd.DataFrame()
dfIncomes = [0]
ageBase = []
ageLimit = []
for item in age_and_sex.iloc[:,0]:
    numbers = re.findall(r'\d+', item)
    ageBase.append(int(numbers[0]))
    if len(numbers) > 1:
        ageLimit.append(int(numbers[1]))
        if(int(numbers[0])>=dfAges.iloc[0][0])&(int(numbers[1])<=dfAges.iloc[0][1]):
            dfIncomes.append(dfAges.iloc[0][2])
        elif(int(numbers[0])>=dfAges.iloc[1][0])&(int(numbers[1])<=dfAges.iloc[1][1]):
            dfIncomes.append(dfAges.iloc[1][2])
        elif(int(numbers[0])>=dfAges.iloc[2][0])&(int(numbers[1])<=dfAges.iloc[2][1]):
            dfIncomes.append(dfAges.iloc[2][2])
        elif(int(numbers[0])>=dfAges.iloc[3][0]):
            dfIncomes.append(dfAges.iloc[3][2])
    else:
        ageLimit.append(-1)
        if(int(numbers[0])>=dfAges.iloc[3][0]):
            dfIncomes.append(dfAges.iloc[3][2])
people_1['ageBase'] = ageBase
people_1['ageLimit'] = ageLimit
people_1['income'] = dfIncomes
people_1
# Out:
#     ageBase  ageLimit   income
# 0         0        14        0
# 1        15        19   530049
# 2        20        24   530049
# 3        25        29  4057366
# 4        30        34  4057366
# 5        35        39  4057366
# 6        40        44  4057366
# 7        45        49  3841670
# 8        50        54  3841670
# 9        55        59  3841670
# 10       60        64  3841670
# 11       65        69  2367162
# 12       70        74  2367162
# 13       75        79  2367162
# 14       80        84  2367162
# 15       85        -1  2367162

# %%
people_2 = age_and_sex
people_2['income'] = dfIncomes
people_2
# Out:
#              ageRange State   income
# 0       0 to 14 years    TX        0
# 1      15 to 19 years    TX   530049
# 2      20 to 24 years    TX   530049
# 3      25 to 29 years    TX  4057366
# 4      30 to 34 years    TX  4057366
# 5      35 to 39 years    TX  4057366
# 6      40 to 44 years    TX  4057366
# 7      45 to 49 years    TX  3841670
# 8      50 to 54 years    TX  3841670
# 9      55 to 59 years    TX  3841670
# 10     60 to 64 years    TX  3841670
# 11     65 to 69 years    TX  2367162
# 12     70 to 74 years    TX  2367162
# 13     75 to 79 years    TX  2367162
# 14     80 to 84 years    TX  2367162
# 15  85 years and over    TX  2367162

# %%
import psycopg2
import psycopg2.extras as extras
import pandas as pd


def execute_values(conn, df, table):

	tuples = [tuple(x) for x in df.to_numpy()]

	cols = ','.join(list(df.columns))
	finish = True
	coma = 0
	cont = 0
	cols_final = '"'
	cols += ","
	while(finish):
		coma = cols.find(",", cont)
		if coma == -1:
			finish = False
			cols_final = cols_final[:-2]
		else:
			var = cols[cont:coma]
			cont = coma + 1
			cols_final += var
			cols_final += '","'


	print(cols_final)
	# SQL query to execute
	query = "INSERT INTO %s(%s) VALUES %%s" % (table, cols_final)
	cursor = conn.cursor()
	try:
		extras.execute_values(cursor, query, tuples)
		conn.commit()
	except (Exception, psycopg2.DatabaseError) as error:
		print("Error: %s" % error)
		conn.rollback()
		cursor.close()
		return 1
	print("execute_values() done")
	cursor.close()

# %%
conn = psycopg2.connect(
  database="proyectoBI",
  user='postgres', 
  password='admin', 
  host='localhost', 
  port= '5432'
)

sql = '''DELETE FROM public."Income";'''
  
#creating a cursor
cursor = conn.cursor()
cursor.execute(sql)
conn.commit()
data = people_2
# using the function defined
execute_values(conn, data, 'public."Income"')
conn.close()
# Out:
# "ageRange","State","income"
# execute_values() done
